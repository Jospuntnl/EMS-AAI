# %% [markdown]
# # Model Training
#
# Here you will load the images, create a model and train it.

# %% [markdown]
# ## Setup

# %%
import cv2
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from tensorflow import keras
import matplotlib as mpl
import random
import PIL
from sklearn.model_selection import train_test_split
from sklearn import metrics

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential

# %% [markdown]
# Specify the dataset directory and the ordered list of labels.

# %%
dataset_dir = './dataset'
class_names = ['left','straight','right']

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# Define a function to preprocess each image

# %%
def preprocess(image):
    scale_percent = 40 # percent of original size
    width = int(image.shape[1] * scale_percent / 100)
    height = int(image.shape[0] * scale_percent / 100)
    dim = (width, height)
    resized = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
    return resized

# %% [markdown]
# Read in each image in the dataset directory, run the preprocessing and then them into a list called `data`. Create a corresponding list of the assigned labels called `data_labels`.  Then at the end, convert the lists to numpy arrays.

# %%
data = []
data_labels = []

for class_idx,class_name in enumerate(class_names):
    dir_name = os.path.join(dataset_dir,class_name)
    for file in os.listdir(dir_name):
        if file.endswith('.png'):
            full_path = os.path.join(dir_name,file)
            image = cv2.imread(full_path)
            preprocessed_image = preprocess(image)
            data.append(preprocessed_image)
            data_labels.append(class_idx)

data = np.array(data)
data_labels = np.array(data_labels)



#--------------- Mirror functionality written by lucanatorvs -------------------------------------------------------------

# we mirror the data to increase the dataset, every image is flipped horizontally, and the label is changed accordingly; left becomes right, right becomes left and straight stays straight

data_mirror = np.flip(data,2)
data_mirror_labels = np.copy(data_labels)
data_mirror_labels[data_mirror_labels == 0] = 3
data_mirror_labels[data_mirror_labels == 2] = 0
data_mirror_labels[data_mirror_labels == 3] = 2

# now we concatenate the original data and the mirrored data to get a bigger dataset
data = np.concatenate((data,data_mirror),axis=0)
data_labels = np.concatenate((data_labels,data_mirror_labels),axis=0)

# now crop the top 20 pixels from the image, to remove the sky and the horizon
data = data[:,25:,:]
#--------------------------------------------------------------------------------------------------------------------------
print(data.shape)
print(data_labels.shape)
# Out:
# (454, 64, 89, 3)
# (454,)

# %% [markdown]
# Plot some of the images to make sure everything went okay.

# %%
rows = 3
columns = 2
fig, axes = plt.subplots(rows,columns,figsize=(6,6))
for i,ax in enumerate(axes.ravel()):
    idx = random.choice(range(data.shape[0]))
    ax.imshow(data[idx],cmap='gray')
    ax.set_title(class_names[data_labels[idx]])
fig.tight_layout()

# %% [markdown]
# Check the dataset dimesions to see how many instances and labels there are.

# %%
print("Dataset shape:",data.shape)
print("Labels shape:", data_labels.shape)
# Out:
# Dataset shape: (454, 64, 89, 3)
# Labels shape: (454,)

# %% [markdown]
# ## Data Splitting / Model Definition / Training / Evaluation

# %% [markdown]
# At this point you have succefully prepared your images for training.  Now you have to split this data into training validation, and test sets, then create a suitable model, train it and then test it, and finally if you are satisfied with your performance you can save the model. The saved model can be later loaded in your Jetracer for deployment.

# %%
# ----------------- Written by lucanatorvs --------------------------------------------------------------
# first we make a test set, and then we split the remaining data into a validation and a training set
X_train, X_test, y_train, y_test = train_test_split(
    data, data_labels, test_size=0.2, random_state=69)
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=69)

# now we print the shape of the data
print('X_train shape:', X_train.shape)
print('X_val shape:', X_val.shape)
print('X_test shape:', X_test.shape)
# -------------------------------------------------------------------------------------------------------


# -------- Model is WIP, should be changed to CNN -------------------------------------------------------

model = Sequential([
    layers.Rescaling(1./255, input_shape=(64, 89, 3)),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.Flatten(),
    layers.Dropout(0.1),
    layers.Dense(32, input_shape=(64,89,3),kernel_regularizer=regularizers.l2(0.01)),
])

# return the constructed network architecture


model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(
                  from_logits=True),
              metrics=['accuracy'])

print(model.summary())
trained = model.fit(X_train, y_train, epochs=100,
                    validation_data=(X_val, y_val))
df = pd.DataFrame(trained.history)
df.plot()
# Out:
# X_train shape: (290, 64, 89, 3)
# X_val shape: (73, 64, 89, 3)
# X_test shape: (91, 64, 89, 3)
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_8 (Rescaling)     (None, 64, 89, 3)         0
#
#  conv2d_20 (Conv2D)          (None, 64, 89, 32)        896
#
#  max_pooling2d_12 (MaxPoolin  (None, 32, 44, 32)       0
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 32, 44, 32)        9248
#
#  flatten_8 (Flatten)         (None, 45056)             0
#
#  dropout_8 (Dropout)         (None, 45056)             0
#
#  dense_13 (Dense)            (None, 32)                1441824
#
# =================================================================
# Total params: 1,451,968
# Trainable params: 1,451,968
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 10/10 [==============================] - 2s 121ms/step - loss: 2.0038 - accuracy: 0.3069 - val_loss: 1.5893 - val_accuracy: 0.2877
# Epoch 2/100
# 10/10 [==============================] - 1s 80ms/step - loss: 1.5736 - accuracy: 0.3621 - val_loss: 1.4693 - val_accuracy: 0.3562
# Epoch 3/100
# 10/10 [==============================] - 1s 80ms/step - loss: 1.4056 - accuracy: 0.4241 - val_loss: 1.3472 - val_accuracy: 0.3562
# Epoch 4/100
# 10/10 [==============================] - 1s 78ms/step - loss: 1.2580 - accuracy: 0.5000 - val_loss: 1.1412 - val_accuracy: 0.7397
# Epoch 5/100
# 10/10 [==============================] - 1s 82ms/step - loss: 1.1122 - accuracy: 0.7103 - val_loss: 1.0515 - val_accuracy: 0.5068
# Epoch 6/100
# 10/10 [==============================] - 1s 80ms/step - loss: 1.0316 - accuracy: 0.5621 - val_loss: 0.9032 - val_accuracy: 0.7534
# Epoch 7/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.8657 - accuracy: 0.7069 - val_loss: 1.0485 - val_accuracy: 0.4521
# Epoch 8/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.8664 - accuracy: 0.7069 - val_loss: 0.8202 - val_accuracy: 0.7671
# Epoch 9/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.6833 - accuracy: 0.7828 - val_loss: 0.7511 - val_accuracy: 0.7534
# Epoch 10/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.6372 - accuracy: 0.8000 - val_loss: 0.7463 - val_accuracy: 0.8219
# Epoch 11/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.5884 - accuracy: 0.8103 - val_loss: 0.6851 - val_accuracy: 0.7945
# Epoch 12/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.5333 - accuracy: 0.8241 - val_loss: 0.6840 - val_accuracy: 0.7808
# Epoch 13/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.4860 - accuracy: 0.8379 - val_loss: 0.6166 - val_accuracy: 0.8219
# Epoch 14/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.4653 - accuracy: 0.8655 - val_loss: 0.7791 - val_accuracy: 0.7397
# Epoch 15/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.5491 - accuracy: 0.8448 - val_loss: 0.6748 - val_accuracy: 0.8219
# Epoch 16/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.4708 - accuracy: 0.8862 - val_loss: 0.7054 - val_accuracy: 0.8904
# Epoch 17/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.4434 - accuracy: 0.8862 - val_loss: 0.6385 - val_accuracy: 0.8767
# Epoch 18/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.3751 - accuracy: 0.9241 - val_loss: 0.6390 - val_accuracy: 0.8493
# Epoch 19/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.3330 - accuracy: 0.9241 - val_loss: 0.6406 - val_accuracy: 0.8904
# Epoch 20/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.3234 - accuracy: 0.9345 - val_loss: 0.6467 - val_accuracy: 0.8493
# Epoch 21/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.3496 - accuracy: 0.9138 - val_loss: 0.6353 - val_accuracy: 0.8767
# Epoch 22/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.2925 - accuracy: 0.9414 - val_loss: 0.6724 - val_accuracy: 0.8219
# Epoch 23/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.3682 - accuracy: 0.9138 - val_loss: 0.6148 - val_accuracy: 0.8630
# Epoch 24/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.2856 - accuracy: 0.9690 - val_loss: 0.6488 - val_accuracy: 0.8904
# Epoch 25/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.2479 - accuracy: 0.9655 - val_loss: 0.6335 - val_accuracy: 0.8493
# Epoch 26/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.2627 - accuracy: 0.9552 - val_loss: 0.6423 - val_accuracy: 0.8767
# Epoch 27/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.2150 - accuracy: 0.9759 - val_loss: 0.6436 - val_accuracy: 0.9041
# Epoch 28/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.2267 - accuracy: 0.9690 - val_loss: 0.7109 - val_accuracy: 0.8904
# Epoch 29/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.2036 - accuracy: 0.9793 - val_loss: 0.5900 - val_accuracy: 0.8767
# Epoch 30/100
# 10/10 [==============================] - 1s 86ms/step - loss: 0.1893 - accuracy: 0.9724 - val_loss: 0.6293 - val_accuracy: 0.8904
# Epoch 31/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.1890 - accuracy: 0.9897 - val_loss: 0.6003 - val_accuracy: 0.8904
# Epoch 32/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.1861 - accuracy: 0.9862 - val_loss: 0.6059 - val_accuracy: 0.8767
# Epoch 33/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.2158 - accuracy: 0.9690 - val_loss: 0.5948 - val_accuracy: 0.8767
# Epoch 34/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.1821 - accuracy: 0.9828 - val_loss: 0.6148 - val_accuracy: 0.8767
# Epoch 35/100
# 10/10 [==============================] - 1s 86ms/step - loss: 0.1665 - accuracy: 0.9931 - val_loss: 0.6856 - val_accuracy: 0.8904
# Epoch 36/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.1586 - accuracy: 0.9897 - val_loss: 0.6135 - val_accuracy: 0.8767
# Epoch 37/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1522 - accuracy: 0.9931 - val_loss: 0.6134 - val_accuracy: 0.8767
# Epoch 38/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.1460 - accuracy: 0.9931 - val_loss: 0.6380 - val_accuracy: 0.8767
# Epoch 39/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.1567 - accuracy: 0.9828 - val_loss: 0.5940 - val_accuracy: 0.8904
# Epoch 40/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.1512 - accuracy: 0.9931 - val_loss: 0.6234 - val_accuracy: 0.8767
# Epoch 41/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1434 - accuracy: 0.9897 - val_loss: 0.6757 - val_accuracy: 0.8904
# Epoch 42/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.1387 - accuracy: 0.9931 - val_loss: 0.6017 - val_accuracy: 0.8767
# Epoch 43/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.1316 - accuracy: 0.9897 - val_loss: 0.5621 - val_accuracy: 0.8767
# Epoch 44/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.1303 - accuracy: 0.9966 - val_loss: 0.5858 - val_accuracy: 0.8767
# Epoch 45/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.1230 - accuracy: 0.9966 - val_loss: 0.5856 - val_accuracy: 0.8767
# Epoch 46/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1335 - accuracy: 0.9897 - val_loss: 0.6601 - val_accuracy: 0.8904
# Epoch 47/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.1203 - accuracy: 0.9897 - val_loss: 0.6370 - val_accuracy: 0.8904
# Epoch 48/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.1148 - accuracy: 0.9966 - val_loss: 0.5927 - val_accuracy: 0.8904
# Epoch 49/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.1145 - accuracy: 0.9966 - val_loss: 1.1451 - val_accuracy: 0.7397
# Epoch 50/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.3827 - accuracy: 0.9103 - val_loss: 0.7101 - val_accuracy: 0.8219
# Epoch 51/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2652 - accuracy: 0.9552 - val_loss: 0.7631 - val_accuracy: 0.8904
# Epoch 52/100
# 10/10 [==============================] - 1s 86ms/step - loss: 0.2040 - accuracy: 0.9793 - val_loss: 0.6892 - val_accuracy: 0.8767
# Epoch 53/100
# 10/10 [==============================] - 1s 87ms/step - loss: 0.1651 - accuracy: 0.9897 - val_loss: 0.6941 - val_accuracy: 0.9041
# Epoch 54/100
# 10/10 [==============================] - 1s 87ms/step - loss: 0.1550 - accuracy: 0.9862 - val_loss: 0.7008 - val_accuracy: 0.9041
# Epoch 55/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1563 - accuracy: 0.9862 - val_loss: 0.7346 - val_accuracy: 0.8630
# Epoch 56/100
# 10/10 [==============================] - 1s 92ms/step - loss: 0.1611 - accuracy: 0.9862 - val_loss: 0.6346 - val_accuracy: 0.9041
# Epoch 57/100
# 10/10 [==============================] - 1s 87ms/step - loss: 0.1472 - accuracy: 0.9966 - val_loss: 0.6474 - val_accuracy: 0.9041
# Epoch 58/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.1356 - accuracy: 0.9931 - val_loss: 0.6318 - val_accuracy: 0.8904
# Epoch 59/100
# 10/10 [==============================] - 1s 88ms/step - loss: 0.1304 - accuracy: 0.9931 - val_loss: 0.6518 - val_accuracy: 0.8904
# Epoch 60/100
# 10/10 [==============================] - 1s 89ms/step - loss: 0.1182 - accuracy: 0.9966 - val_loss: 0.6176 - val_accuracy: 0.8904
# Epoch 61/100
# 10/10 [==============================] - 1s 90ms/step - loss: 0.1084 - accuracy: 1.0000 - val_loss: 0.6121 - val_accuracy: 0.8767
# Epoch 62/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.1065 - accuracy: 0.9966 - val_loss: 0.6366 - val_accuracy: 0.8904
# Epoch 63/100
# 10/10 [==============================] - 1s 94ms/step - loss: 0.1112 - accuracy: 0.9966 - val_loss: 0.6598 - val_accuracy: 0.8767
# Epoch 64/100
# 10/10 [==============================] - 1s 88ms/step - loss: 0.1046 - accuracy: 0.9966 - val_loss: 0.6243 - val_accuracy: 0.8767
# Epoch 65/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0987 - accuracy: 0.9966 - val_loss: 0.7152 - val_accuracy: 0.8904
# Epoch 66/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0950 - accuracy: 1.0000 - val_loss: 0.6178 - val_accuracy: 0.8904
# Epoch 67/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0920 - accuracy: 0.9966 - val_loss: 0.6484 - val_accuracy: 0.8904
# Epoch 68/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0913 - accuracy: 0.9966 - val_loss: 0.6279 - val_accuracy: 0.8767
# Epoch 69/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0888 - accuracy: 0.9966 - val_loss: 0.6469 - val_accuracy: 0.8767
# Epoch 70/100
# 10/10 [==============================] - 1s 87ms/step - loss: 0.0892 - accuracy: 0.9966 - val_loss: 0.6264 - val_accuracy: 0.8767
# Epoch 71/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0828 - accuracy: 1.0000 - val_loss: 1.2748 - val_accuracy: 0.7123
# Epoch 72/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.2369 - accuracy: 0.9414 - val_loss: 0.6867 - val_accuracy: 0.8630
# Epoch 73/100
# 10/10 [==============================] - 1s 90ms/step - loss: 0.1699 - accuracy: 0.9793 - val_loss: 0.8261 - val_accuracy: 0.9041
# Epoch 74/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.1323 - accuracy: 0.9897 - val_loss: 0.7976 - val_accuracy: 0.8904
# Epoch 75/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.1115 - accuracy: 0.9966 - val_loss: 0.7791 - val_accuracy: 0.8767
# Epoch 76/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.1003 - accuracy: 0.9966 - val_loss: 0.7949 - val_accuracy: 0.8767
# Epoch 77/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0919 - accuracy: 1.0000 - val_loss: 0.7722 - val_accuracy: 0.8767
# Epoch 78/100
# 10/10 [==============================] - 1s 90ms/step - loss: 0.0881 - accuracy: 1.0000 - val_loss: 0.7156 - val_accuracy: 0.8904
# Epoch 79/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0863 - accuracy: 0.9966 - val_loss: 0.7541 - val_accuracy: 0.8767
# Epoch 80/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0835 - accuracy: 1.0000 - val_loss: 0.6815 - val_accuracy: 0.8904
# Epoch 81/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0757 - accuracy: 1.0000 - val_loss: 0.7186 - val_accuracy: 0.8767
# Epoch 82/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0743 - accuracy: 1.0000 - val_loss: 0.6922 - val_accuracy: 0.8767
# Epoch 83/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0746 - accuracy: 1.0000 - val_loss: 0.6573 - val_accuracy: 0.8767
# Epoch 84/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0715 - accuracy: 1.0000 - val_loss: 0.6752 - val_accuracy: 0.8904
# Epoch 85/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0716 - accuracy: 0.9966 - val_loss: 0.6594 - val_accuracy: 0.8767
# Epoch 86/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0729 - accuracy: 0.9966 - val_loss: 0.6648 - val_accuracy: 0.8767
# Epoch 87/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0707 - accuracy: 0.9966 - val_loss: 0.7196 - val_accuracy: 0.8767
# Epoch 88/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0699 - accuracy: 1.0000 - val_loss: 0.6310 - val_accuracy: 0.8904
# Epoch 89/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0804 - accuracy: 0.9966 - val_loss: 0.6638 - val_accuracy: 0.8630
# Epoch 90/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0790 - accuracy: 0.9966 - val_loss: 0.6044 - val_accuracy: 0.8767
# Epoch 91/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0758 - accuracy: 0.9931 - val_loss: 0.6919 - val_accuracy: 0.8904
# Epoch 92/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0800 - accuracy: 0.9931 - val_loss: 0.6201 - val_accuracy: 0.8767
# Epoch 93/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0690 - accuracy: 1.0000 - val_loss: 0.6147 - val_accuracy: 0.8767
# Epoch 94/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0704 - accuracy: 0.9966 - val_loss: 0.6508 - val_accuracy: 0.8767
# Epoch 95/100
# 10/10 [==============================] - 1s 88ms/step - loss: 0.0763 - accuracy: 0.9966 - val_loss: 0.6207 - val_accuracy: 0.8767
# Epoch 96/100
# 10/10 [==============================] - 1s 86ms/step - loss: 0.1022 - accuracy: 0.9828 - val_loss: 0.8391 - val_accuracy: 0.8493
# Epoch 97/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1403 - accuracy: 0.9690 - val_loss: 0.6951 - val_accuracy: 0.9041
# Epoch 98/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1157 - accuracy: 0.9897 - val_loss: 0.6821 - val_accuracy: 0.8356
# Epoch 99/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.1053 - accuracy: 0.9931 - val_loss: 0.7766 - val_accuracy: 0.8904
# Epoch 100/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1041 - accuracy: 0.9931 - val_loss: 0.6856 - val_accuracy: 0.9041
# <AxesSubplot:>

# %% [markdown]
# ## Saving a TensorFlow Lite Model

# %% [markdown]
# Choose an appropriate output file name for your `.tflite` file.  It may help to use version numbers, and keep track of versions

# %%
output_filename = './mini_proj_model_v01_01.tflite'

# %% [markdown]
# Convert your model (in the variable `model`) and save the `.tflite` file

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

converter.target_spec.supported_types = [tf.float16]
tflite_fp16_model = converter.convert()

# This will save your model with the a file name tflite_model_fp16_file.tflite. You can uplaod this model file
# in your JetRacer a

with open(output_filename, 'wb') as f:
    f.write(tflite_fp16_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\joskn\AppData\Local\Temp\tmpcrkc_2c4\assets
# INFO:tensorflow:Assets written to: C:\Users\joskn\AppData\Local\Temp\tmpcrkc_2c4\assets
