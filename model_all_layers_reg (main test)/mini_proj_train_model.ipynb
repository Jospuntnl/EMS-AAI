# %% [markdown]
# # Model Training
#
# Here you will load the images, create a model and train it.

# %% [markdown]
# ## Setup

# %%
import cv2
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from tensorflow import keras
import matplotlib as mpl
import random
import PIL
from sklearn.model_selection import train_test_split
from sklearn import metrics

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential

# %% [markdown]
# Specify the dataset directory and the ordered list of labels.

# %%
dataset_dir = './dataset'
class_names = ['left','straight','right']

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# Define a function to preprocess each image

# %%
def preprocess(image):
    scale_percent = 40 # percent of original size
    width = int(image.shape[1] * scale_percent / 100)
    height = int(image.shape[0] * scale_percent / 100)
    dim = (width, height)
    resized = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
    return resized

# %% [markdown]
# Read in each image in the dataset directory, run the preprocessing and then them into a list called `data`. Create a corresponding list of the assigned labels called `data_labels`.  Then at the end, convert the lists to numpy arrays.

# %%
data = []
data_labels = []

for class_idx,class_name in enumerate(class_names):
    dir_name = os.path.join(dataset_dir,class_name)
    for file in os.listdir(dir_name):
        if file.endswith('.png'):
            full_path = os.path.join(dir_name,file)
            image = cv2.imread(full_path)
            preprocessed_image = preprocess(image)
            data.append(preprocessed_image)
            data_labels.append(class_idx)

data = np.array(data)
data_labels = np.array(data_labels)



#--------------- Mirror functionality written by lucanatorvs -------------------------------------------------------------

# we mirror the data to increase the dataset, every image is flipped horizontally, and the label is changed accordingly; left becomes right, right becomes left and straight stays straight

data_mirror = np.flip(data,2)
data_mirror_labels = np.copy(data_labels)
data_mirror_labels[data_mirror_labels == 0] = 3
data_mirror_labels[data_mirror_labels == 2] = 0
data_mirror_labels[data_mirror_labels == 3] = 2

# now we concatenate the original data and the mirrored data to get a bigger dataset
data = np.concatenate((data,data_mirror),axis=0)
data_labels = np.concatenate((data_labels,data_mirror_labels),axis=0)

# now crop the top 20 pixels from the image, to remove the sky and the horizon
data = data[:,25:,:]
#--------------------------------------------------------------------------------------------------------------------------
print(data.shape)
print(data_labels.shape)
# Out:
# (454, 64, 89, 3)
# (454,)

# %% [markdown]
# Plot some of the images to make sure everything went okay.

# %%
rows = 3
columns = 2
fig, axes = plt.subplots(rows,columns,figsize=(6,6))
for i,ax in enumerate(axes.ravel()):
    idx = random.choice(range(data.shape[0]))
    ax.imshow(data[idx],cmap='gray')
    ax.set_title(class_names[data_labels[idx]])
fig.tight_layout()

# %% [markdown]
# Check the dataset dimesions to see how many instances and labels there are.

# %%
print("Dataset shape:",data.shape)
print("Labels shape:", data_labels.shape)
# Out:
# Dataset shape: (454, 64, 89, 3)
# Labels shape: (454,)

# %% [markdown]
# ## Data Splitting / Model Definition / Training / Evaluation

# %% [markdown]
# At this point you have succefully prepared your images for training.  Now you have to split this data into training validation, and test sets, then create a suitable model, train it and then test it, and finally if you are satisfied with your performance you can save the model. The saved model can be later loaded in your Jetracer for deployment.

# %%
# ----------------- Written by lucanatorvs --------------------------------------------------------------
# first we make a test set, and then we split the remaining data into a validation and a training set
X_train, X_test, y_train, y_test = train_test_split(
    data, data_labels, test_size=0.2, random_state=69)
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=69)

# now we print the shape of the data
print('X_train shape:', X_train.shape)
print('X_val shape:', X_val.shape)
print('X_test shape:', X_test.shape)
# -------------------------------------------------------------------------------------------------------


# -------- Model is WIP, should be changed to CNN -------------------------------------------------------

model = Sequential([
    layers.Rescaling(1./255, input_shape=(64, 89, 3)),
    layers.Conv2D(16, 3, padding='same', activation='relu',kernel_regularizer=regularizers.l2(l=0.01)),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', activation='relu',kernel_regularizer=regularizers.l2(l=0.01)),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu',kernel_regularizer=regularizers.l2(l=0.01)),
    layers.MaxPooling2D(),
    layers.Conv2D(128, 3, padding='same', activation='relu',kernel_regularizer=regularizers.l2(l=0.01)),
    layers.Flatten(),
    layers.Dropout(0.1),
    layers.Dense(3)
])

# return the constructed network architecture


model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(
                  from_logits=True),
              metrics=['accuracy'])

print(model.summary())
trained = model.fit(X_train, y_train, epochs=100,
                    validation_data=(X_val, y_val))
df = pd.DataFrame(trained.history)
df.plot()
# Out:
# X_train shape: (290, 64, 89, 3)
# X_val shape: (73, 64, 89, 3)
# X_test shape: (91, 64, 89, 3)
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_10 (Rescaling)    (None, 64, 89, 3)         0
#
#  conv2d_26 (Conv2D)          (None, 64, 89, 16)        448
#
#  max_pooling2d_16 (MaxPoolin  (None, 32, 44, 16)       0
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 32, 44, 32)        4640
#
#  max_pooling2d_17 (MaxPoolin  (None, 16, 22, 32)       0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 16, 22, 64)        18496
#
#  max_pooling2d_18 (MaxPoolin  (None, 8, 11, 64)        0
#  g2D)
#
#  conv2d_29 (Conv2D)          (None, 8, 11, 128)        73856
#
#  flatten_10 (Flatten)        (None, 11264)             0
#
#  dropout_10 (Dropout)        (None, 11264)             0
#
#  dense_14 (Dense)            (None, 3)                 33795
#
# =================================================================
# Total params: 131,235
# Trainable params: 131,235
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 10/10 [==============================] - 1s 89ms/step - loss: 2.4503 - accuracy: 0.3759 - val_loss: 2.1627 - val_accuracy: 0.3562
# Epoch 2/100
# 10/10 [==============================] - 1s 62ms/step - loss: 2.0036 - accuracy: 0.3897 - val_loss: 1.7820 - val_accuracy: 0.4795
# Epoch 3/100
# 10/10 [==============================] - 1s 58ms/step - loss: 1.6410 - accuracy: 0.5690 - val_loss: 1.3753 - val_accuracy: 0.7123
# Epoch 4/100
# 10/10 [==============================] - 1s 59ms/step - loss: 1.2023 - accuracy: 0.7276 - val_loss: 1.1186 - val_accuracy: 0.7534
# Epoch 5/100
# 10/10 [==============================] - 1s 69ms/step - loss: 1.0164 - accuracy: 0.7724 - val_loss: 0.9787 - val_accuracy: 0.7808
# Epoch 6/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.7979 - accuracy: 0.8000 - val_loss: 0.8471 - val_accuracy: 0.8082
# Epoch 7/100
# 10/10 [==============================] - 1s 60ms/step - loss: 0.6918 - accuracy: 0.8345 - val_loss: 0.7436 - val_accuracy: 0.8493
# Epoch 8/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.6139 - accuracy: 0.8448 - val_loss: 0.6905 - val_accuracy: 0.8630
# Epoch 9/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.5262 - accuracy: 0.9034 - val_loss: 0.7000 - val_accuracy: 0.8493
# Epoch 10/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.4913 - accuracy: 0.9034 - val_loss: 0.6360 - val_accuracy: 0.8630
# Epoch 11/100
# 10/10 [==============================] - 1s 60ms/step - loss: 0.5789 - accuracy: 0.8448 - val_loss: 0.7314 - val_accuracy: 0.8630
# Epoch 12/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.5417 - accuracy: 0.8759 - val_loss: 0.6853 - val_accuracy: 0.8356
# Epoch 13/100
# 10/10 [==============================] - 1s 58ms/step - loss: 0.4777 - accuracy: 0.8966 - val_loss: 0.6277 - val_accuracy: 0.8630
# Epoch 14/100
# 10/10 [==============================] - 1s 60ms/step - loss: 0.4184 - accuracy: 0.9241 - val_loss: 0.6150 - val_accuracy: 0.8630
# Epoch 15/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.4062 - accuracy: 0.9034 - val_loss: 0.6278 - val_accuracy: 0.8904
# Epoch 16/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.3961 - accuracy: 0.9276 - val_loss: 0.6000 - val_accuracy: 0.8767
# Epoch 17/100
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3543 - accuracy: 0.9483 - val_loss: 0.6355 - val_accuracy: 0.8767
# Epoch 18/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.3548 - accuracy: 0.9345 - val_loss: 0.5792 - val_accuracy: 0.8630
# Epoch 19/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.3457 - accuracy: 0.9448 - val_loss: 0.5582 - val_accuracy: 0.8767
# Epoch 20/100
# 10/10 [==============================] - 1s 60ms/step - loss: 0.3758 - accuracy: 0.9276 - val_loss: 0.6665 - val_accuracy: 0.8493
# Epoch 21/100
# 10/10 [==============================] - 1s 60ms/step - loss: 0.4296 - accuracy: 0.9172 - val_loss: 0.6188 - val_accuracy: 0.8767
# Epoch 22/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.3392 - accuracy: 0.9345 - val_loss: 0.6493 - val_accuracy: 0.8904
# Epoch 23/100
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3324 - accuracy: 0.9345 - val_loss: 0.5871 - val_accuracy: 0.8904
# Epoch 24/100
# 10/10 [==============================] - 1s 60ms/step - loss: 0.5519 - accuracy: 0.8931 - val_loss: 0.6561 - val_accuracy: 0.8630
# Epoch 25/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.3930 - accuracy: 0.9103 - val_loss: 0.8378 - val_accuracy: 0.8630
# Epoch 26/100
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3812 - accuracy: 0.9345 - val_loss: 0.6812 - val_accuracy: 0.8767
# Epoch 27/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.3244 - accuracy: 0.9345 - val_loss: 0.6501 - val_accuracy: 0.8630
# Epoch 28/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.3074 - accuracy: 0.9414 - val_loss: 0.6776 - val_accuracy: 0.8767
# Epoch 29/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.2997 - accuracy: 0.9310 - val_loss: 0.7091 - val_accuracy: 0.8767
# Epoch 30/100
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3000 - accuracy: 0.9448 - val_loss: 0.6494 - val_accuracy: 0.8630
# Epoch 31/100
# 10/10 [==============================] - 1s 60ms/step - loss: 0.2818 - accuracy: 0.9483 - val_loss: 0.6625 - val_accuracy: 0.8630
# Epoch 32/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.2707 - accuracy: 0.9483 - val_loss: 0.6278 - val_accuracy: 0.8767
# Epoch 33/100
# 10/10 [==============================] - 1s 59ms/step - loss: 0.2605 - accuracy: 0.9414 - val_loss: 0.6477 - val_accuracy: 0.8767
# Epoch 34/100
# 10/10 [==============================] - 1s 60ms/step - loss: 0.2555 - accuracy: 0.9483 - val_loss: 0.6308 - val_accuracy: 0.8767
# Epoch 35/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.2591 - accuracy: 0.9448 - val_loss: 0.6741 - val_accuracy: 0.8904
# Epoch 36/100
# 10/10 [==============================] - 1s 59ms/step - loss: 0.2566 - accuracy: 0.9517 - val_loss: 0.6667 - val_accuracy: 0.8493
# Epoch 37/100
# 10/10 [==============================] - 1s 60ms/step - loss: 0.2504 - accuracy: 0.9517 - val_loss: 0.6661 - val_accuracy: 0.9041
# Epoch 38/100
# 10/10 [==============================] - 1s 60ms/step - loss: 0.2574 - accuracy: 0.9414 - val_loss: 0.6962 - val_accuracy: 0.8767
# Epoch 39/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.2453 - accuracy: 0.9448 - val_loss: 0.6710 - val_accuracy: 0.8904
# Epoch 40/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.2326 - accuracy: 0.9517 - val_loss: 0.6535 - val_accuracy: 0.8904
# Epoch 41/100
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2255 - accuracy: 0.9621 - val_loss: 0.6300 - val_accuracy: 0.8904
# Epoch 42/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.2202 - accuracy: 0.9483 - val_loss: 0.6578 - val_accuracy: 0.8904
# Epoch 43/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.2236 - accuracy: 0.9483 - val_loss: 0.6907 - val_accuracy: 0.8767
# Epoch 44/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.2123 - accuracy: 0.9552 - val_loss: 0.6727 - val_accuracy: 0.9041
# Epoch 45/100
# 10/10 [==============================] - 1s 64ms/step - loss: 0.2069 - accuracy: 0.9621 - val_loss: 0.6746 - val_accuracy: 0.9041
# Epoch 46/100
# 10/10 [==============================] - 1s 60ms/step - loss: 0.2132 - accuracy: 0.9552 - val_loss: 0.7115 - val_accuracy: 0.8219
# Epoch 47/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.3204 - accuracy: 0.9310 - val_loss: 0.7357 - val_accuracy: 0.8767
# Epoch 48/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.2722 - accuracy: 0.9586 - val_loss: 0.8099 - val_accuracy: 0.8904
# Epoch 49/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.2295 - accuracy: 0.9586 - val_loss: 0.7908 - val_accuracy: 0.8767
# Epoch 50/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.2138 - accuracy: 0.9655 - val_loss: 0.8007 - val_accuracy: 0.9041
# Epoch 51/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.2055 - accuracy: 0.9586 - val_loss: 0.7878 - val_accuracy: 0.8904
# Epoch 52/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.1995 - accuracy: 0.9793 - val_loss: 0.7409 - val_accuracy: 0.8767
# Epoch 53/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.2399 - accuracy: 0.9621 - val_loss: 0.7588 - val_accuracy: 0.8767
# Epoch 54/100
# 10/10 [==============================] - 1s 67ms/step - loss: 0.2040 - accuracy: 0.9655 - val_loss: 0.8411 - val_accuracy: 0.8904
# Epoch 55/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.2125 - accuracy: 0.9724 - val_loss: 0.6912 - val_accuracy: 0.8767
# Epoch 56/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.2056 - accuracy: 0.9724 - val_loss: 0.6951 - val_accuracy: 0.9041
# Epoch 57/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.2030 - accuracy: 0.9759 - val_loss: 0.7757 - val_accuracy: 0.8904
# Epoch 58/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.1926 - accuracy: 0.9828 - val_loss: 0.7606 - val_accuracy: 0.8493
# Epoch 59/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.2945 - accuracy: 0.9517 - val_loss: 0.7832 - val_accuracy: 0.8493
# Epoch 60/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.2360 - accuracy: 0.9621 - val_loss: 0.8659 - val_accuracy: 0.8767
# Epoch 61/100
# 10/10 [==============================] - 1s 64ms/step - loss: 0.3765 - accuracy: 0.9172 - val_loss: 0.6874 - val_accuracy: 0.8493
# Epoch 62/100
# 10/10 [==============================] - 1s 60ms/step - loss: 0.2886 - accuracy: 0.9345 - val_loss: 0.6587 - val_accuracy: 0.8493
# Epoch 63/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.2498 - accuracy: 0.9621 - val_loss: 0.7892 - val_accuracy: 0.8904
# Epoch 64/100
# 10/10 [==============================] - 1s 65ms/step - loss: 0.2418 - accuracy: 0.9621 - val_loss: 0.7030 - val_accuracy: 0.8767
# Epoch 65/100
# 10/10 [==============================] - 1s 59ms/step - loss: 0.2047 - accuracy: 0.9621 - val_loss: 0.6648 - val_accuracy: 0.9041
# Epoch 66/100
# 10/10 [==============================] - 1s 64ms/step - loss: 0.1967 - accuracy: 0.9759 - val_loss: 0.6366 - val_accuracy: 0.9041
# Epoch 67/100
# 10/10 [==============================] - 1s 64ms/step - loss: 0.1853 - accuracy: 0.9759 - val_loss: 0.6905 - val_accuracy: 0.9041
# Epoch 68/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.1833 - accuracy: 0.9793 - val_loss: 0.6928 - val_accuracy: 0.9041
# Epoch 69/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.1797 - accuracy: 0.9759 - val_loss: 0.7097 - val_accuracy: 0.9041
# Epoch 70/100
# 10/10 [==============================] - 1s 65ms/step - loss: 0.1702 - accuracy: 0.9862 - val_loss: 0.6916 - val_accuracy: 0.8904
# Epoch 71/100
# 10/10 [==============================] - 1s 65ms/step - loss: 0.1742 - accuracy: 0.9793 - val_loss: 0.7088 - val_accuracy: 0.9041
# Epoch 72/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.1642 - accuracy: 0.9862 - val_loss: 0.6885 - val_accuracy: 0.9041
# Epoch 73/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.1660 - accuracy: 0.9759 - val_loss: 0.7219 - val_accuracy: 0.9041
# Epoch 74/100
# 10/10 [==============================] - 1s 64ms/step - loss: 0.1722 - accuracy: 0.9793 - val_loss: 0.7174 - val_accuracy: 0.9041
# Epoch 75/100
# 10/10 [==============================] - 1s 60ms/step - loss: 0.1814 - accuracy: 0.9828 - val_loss: 0.6770 - val_accuracy: 0.8904
# Epoch 76/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.1770 - accuracy: 0.9759 - val_loss: 0.7643 - val_accuracy: 0.8904
# Epoch 77/100
# 10/10 [==============================] - 1s 64ms/step - loss: 0.1785 - accuracy: 0.9724 - val_loss: 0.7261 - val_accuracy: 0.9041
# Epoch 78/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.1680 - accuracy: 0.9759 - val_loss: 0.7098 - val_accuracy: 0.9041
# Epoch 79/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.1603 - accuracy: 0.9828 - val_loss: 0.7184 - val_accuracy: 0.9041
# Epoch 80/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.1620 - accuracy: 0.9828 - val_loss: 0.7095 - val_accuracy: 0.8904
# Epoch 81/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.1560 - accuracy: 0.9931 - val_loss: 0.7128 - val_accuracy: 0.8904
# Epoch 82/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.1483 - accuracy: 0.9897 - val_loss: 0.7619 - val_accuracy: 0.9041
# Epoch 83/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.1455 - accuracy: 0.9897 - val_loss: 0.6982 - val_accuracy: 0.8767
# Epoch 84/100
# 10/10 [==============================] - 1s 65ms/step - loss: 0.1675 - accuracy: 0.9690 - val_loss: 0.7288 - val_accuracy: 0.9041
# Epoch 85/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.1571 - accuracy: 0.9862 - val_loss: 0.6861 - val_accuracy: 0.9041
# Epoch 86/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.1532 - accuracy: 0.9793 - val_loss: 0.7615 - val_accuracy: 0.9041
# Epoch 87/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.1482 - accuracy: 0.9897 - val_loss: 0.7461 - val_accuracy: 0.8904
# Epoch 88/100
# 10/10 [==============================] - 1s 61ms/step - loss: 0.1409 - accuracy: 0.9897 - val_loss: 0.7395 - val_accuracy: 0.9041
# Epoch 89/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.1392 - accuracy: 0.9931 - val_loss: 0.7312 - val_accuracy: 0.9041
# Epoch 90/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.1386 - accuracy: 0.9931 - val_loss: 0.6873 - val_accuracy: 0.8904
# Epoch 91/100
# 10/10 [==============================] - 1s 60ms/step - loss: 0.1427 - accuracy: 0.9897 - val_loss: 0.7260 - val_accuracy: 0.9178
# Epoch 92/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.1423 - accuracy: 0.9862 - val_loss: 0.7212 - val_accuracy: 0.8904
# Epoch 93/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.1393 - accuracy: 0.9897 - val_loss: 0.7480 - val_accuracy: 0.9041
# Epoch 94/100
# 10/10 [==============================] - 1s 60ms/step - loss: 0.1410 - accuracy: 0.9897 - val_loss: 0.6803 - val_accuracy: 0.8904
# Epoch 95/100
# 10/10 [==============================] - 1s 63ms/step - loss: 0.1470 - accuracy: 0.9862 - val_loss: 0.7621 - val_accuracy: 0.8904
# Epoch 96/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.1979 - accuracy: 0.9759 - val_loss: 0.7358 - val_accuracy: 0.8767
# Epoch 97/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.1669 - accuracy: 0.9724 - val_loss: 0.7108 - val_accuracy: 0.8904
# Epoch 98/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.1528 - accuracy: 0.9828 - val_loss: 0.6690 - val_accuracy: 0.8904
# Epoch 99/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.1478 - accuracy: 0.9897 - val_loss: 0.7151 - val_accuracy: 0.9041
# Epoch 100/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.1423 - accuracy: 0.9897 - val_loss: 0.7083 - val_accuracy: 0.8767
# <AxesSubplot:>

# %% [markdown]
# ## Saving a TensorFlow Lite Model

# %% [markdown]
# Choose an appropriate output file name for your `.tflite` file.  It may help to use version numbers, and keep track of versions

# %%
output_filename = './mini_proj_model_v01_01.tflite'

# %% [markdown]
# Convert your model (in the variable `model`) and save the `.tflite` file

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

converter.target_spec.supported_types = [tf.float16]
tflite_fp16_model = converter.convert()

# This will save your model with the a file name tflite_model_fp16_file.tflite. You can uplaod this model file
# in your JetRacer a

with open(output_filename, 'wb') as f:
    f.write(tflite_fp16_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\joskn\AppData\Local\Temp\tmp70g3qibn\assets
# INFO:tensorflow:Assets written to: C:\Users\joskn\AppData\Local\Temp\tmp70g3qibn\assets
