# %% [markdown]
# # Model Training
#
# Here you will load the images, create a model and train it.

# %% [markdown]
# ## Setup

# %%
import cv2
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from tensorflow import keras
import matplotlib as mpl
import random
import PIL
from sklearn.model_selection import train_test_split
from sklearn import metrics

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential

# %% [markdown]
# Specify the dataset directory and the ordered list of labels.

# %%
dataset_dir = './dataset'
class_names = ['left','straight','right']

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# Define a function to preprocess each image

# %%
def preprocess(image):
    scale_percent = 40 # percent of original size
    width = int(image.shape[1] * scale_percent / 100)
    height = int(image.shape[0] * scale_percent / 100)
    dim = (width, height)
    resized = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
    return resized

# %% [markdown]
# Read in each image in the dataset directory, run the preprocessing and then them into a list called `data`. Create a corresponding list of the assigned labels called `data_labels`.  Then at the end, convert the lists to numpy arrays.

# %%
data = []
data_labels = []

for class_idx,class_name in enumerate(class_names):
    dir_name = os.path.join(dataset_dir,class_name)
    for file in os.listdir(dir_name):
        if file.endswith('.png'):
            full_path = os.path.join(dir_name,file)
            image = cv2.imread(full_path)
            preprocessed_image = preprocess(image)
            data.append(preprocessed_image)
            data_labels.append(class_idx)

data = np.array(data)
data_labels = np.array(data_labels)



#--------------- Mirror functionality written by lucanatorvs -------------------------------------------------------------

# we mirror the data to increase the dataset, every image is flipped horizontally, and the label is changed accordingly; left becomes right, right becomes left and straight stays straight

data_mirror = np.flip(data,2)
data_mirror_labels = np.copy(data_labels)
data_mirror_labels[data_mirror_labels == 0] = 3
data_mirror_labels[data_mirror_labels == 2] = 0
data_mirror_labels[data_mirror_labels == 3] = 2

# now we concatenate the original data and the mirrored data to get a bigger dataset
data = np.concatenate((data,data_mirror),axis=0)
data_labels = np.concatenate((data_labels,data_mirror_labels),axis=0)

# now crop the top 20 pixels from the image, to remove the sky and the horizon
data = data[:,25:,:]
#--------------------------------------------------------------------------------------------------------------------------
print(data.shape)
print(data_labels.shape)
# Out:
# (444, 64, 89, 3)
# (444,)

# %% [markdown]
# Plot some of the images to make sure everything went okay.

# %%
rows = 3
columns = 2
fig, axes = plt.subplots(rows,columns,figsize=(6,6))
for i,ax in enumerate(axes.ravel()):
    idx = random.choice(range(data.shape[0]))
    ax.imshow(data[idx],cmap='gray')
    ax.set_title(class_names[data_labels[idx]])
fig.tight_layout()

# %% [markdown]
# Check the dataset dimesions to see how many instances and labels there are.

# %%
print("Dataset shape:",data.shape)
print("Labels shape:", data_labels.shape)
# Out:
# Dataset shape: (444, 64, 89, 3)
# Labels shape: (444,)

# %% [markdown]
# ## Data Splitting / Model Definition / Training / Evaluation

# %% [markdown]
# At this point you have succefully prepared your images for training.  Now you have to split this data into training validation, and test sets, then create a suitable model, train it and then test it, and finally if you are satisfied with your performance you can save the model. The saved model can be later loaded in your Jetracer for deployment.

# %%
# ----------------- Written by lucanatorvs --------------------------------------------------------------
# first we make a test set, and then we split the remaining data into a validation and a training set
X_train, X_test, y_train, y_test = train_test_split(
    data, data_labels, test_size=0.2, random_state=69)
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=69)

# now we print the shape of the data
print('X_train shape:', X_train.shape)
print('X_val shape:', X_val.shape)
print('X_test shape:', X_test.shape)
# -------------------------------------------------------------------------------------------------------


# -------- Model is WIP, should be changed to CNN -------------------------------------------------------

model = Sequential([
    layers.Rescaling(1./255, input_shape=(64, 89, 3)),
    layers.Conv2D(16, 3, padding='same', activation='relu',kernel_regularizer=regularizers.l2(l=0.01)),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', activation='relu',kernel_regularizer=regularizers.l2(l=0.01)),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu',kernel_regularizer=regularizers.l2(l=0.01)),
    layers.MaxPooling2D(),
    layers.Conv2D(128, 3, padding='same', activation='relu',kernel_regularizer=regularizers.l2(l=0.01)),
    layers.Flatten(),
    layers.Dropout(0.1),
    layers.Dense(3)
])

# return the constructed network architecture


model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(
                  from_logits=True),
              metrics=['accuracy'])

print(model.summary())
trained = model.fit(X_train, y_train, epochs=100,
                    validation_data=(X_val, y_val))
df = pd.DataFrame(trained.history)
df.plot()
# Out:
# X_train shape: (284, 64, 89, 3)
# X_val shape: (71, 64, 89, 3)
# X_test shape: (89, 64, 89, 3)
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_6 (Rescaling)     (None, 64, 89, 3)         0
#
#  conv2d_24 (Conv2D)          (None, 64, 89, 16)        448
#
#  max_pooling2d_18 (MaxPoolin  (None, 32, 44, 16)       0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 32, 44, 32)        4640
#
#  max_pooling2d_19 (MaxPoolin  (None, 16, 22, 32)       0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 16, 22, 64)        18496
#
#  max_pooling2d_20 (MaxPoolin  (None, 8, 11, 64)        0
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 8, 11, 128)        73856
#
#  flatten_6 (Flatten)         (None, 11264)             0
#
#  dropout_6 (Dropout)         (None, 11264)             0
#
#  dense_5 (Dense)             (None, 3)                 33795
#
# =================================================================
# Total params: 131,235
# Trainable params: 131,235
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 9/9 [==============================] - 2s 121ms/step - loss: 2.4628 - accuracy: 0.3486 - val_loss: 2.2303 - val_accuracy: 0.3239
# Epoch 2/100
# 9/9 [==============================] - 1s 80ms/step - loss: 2.0817 - accuracy: 0.3627 - val_loss: 1.9069 - val_accuracy: 0.3521
# Epoch 3/100
# 9/9 [==============================] - 1s 78ms/step - loss: 1.7981 - accuracy: 0.4296 - val_loss: 1.6631 - val_accuracy: 0.5775
# Epoch 4/100
# 9/9 [==============================] - 1s 79ms/step - loss: 1.5816 - accuracy: 0.5000 - val_loss: 1.4707 - val_accuracy: 0.6338
# Epoch 5/100
# 9/9 [==============================] - 1s 76ms/step - loss: 1.3599 - accuracy: 0.7183 - val_loss: 1.1640 - val_accuracy: 0.7606
# Epoch 6/100
# 9/9 [==============================] - 1s 81ms/step - loss: 1.0562 - accuracy: 0.7324 - val_loss: 0.9263 - val_accuracy: 0.7887
# Epoch 7/100
# 9/9 [==============================] - 1s 91ms/step - loss: 0.9201 - accuracy: 0.7852 - val_loss: 0.9275 - val_accuracy: 0.7746
# Epoch 8/100
# 9/9 [==============================] - 1s 84ms/step - loss: 0.8095 - accuracy: 0.7993 - val_loss: 0.7629 - val_accuracy: 0.7606
# Epoch 9/100
# 9/9 [==============================] - 1s 83ms/step - loss: 0.7245 - accuracy: 0.8380 - val_loss: 0.7099 - val_accuracy: 0.7746
# Epoch 10/100
# 9/9 [==============================] - 1s 80ms/step - loss: 0.7032 - accuracy: 0.8380 - val_loss: 0.8210 - val_accuracy: 0.7746
# Epoch 11/100
# 9/9 [==============================] - 1s 77ms/step - loss: 0.6385 - accuracy: 0.8592 - val_loss: 0.6691 - val_accuracy: 0.8028
# Epoch 12/100
# 9/9 [==============================] - 1s 76ms/step - loss: 0.6229 - accuracy: 0.8662 - val_loss: 0.6116 - val_accuracy: 0.8310
# Epoch 13/100
# 9/9 [==============================] - 1s 78ms/step - loss: 0.5867 - accuracy: 0.8803 - val_loss: 0.7040 - val_accuracy: 0.8451
# Epoch 14/100
# 9/9 [==============================] - 1s 79ms/step - loss: 0.5240 - accuracy: 0.8873 - val_loss: 0.6262 - val_accuracy: 0.8310
# Epoch 15/100
# 9/9 [==============================] - 1s 77ms/step - loss: 0.4889 - accuracy: 0.9190 - val_loss: 0.5723 - val_accuracy: 0.8310
# Epoch 16/100
# 9/9 [==============================] - 1s 73ms/step - loss: 0.4561 - accuracy: 0.9190 - val_loss: 0.5687 - val_accuracy: 0.8451
# Epoch 17/100
# 9/9 [==============================] - 1s 74ms/step - loss: 0.4426 - accuracy: 0.9331 - val_loss: 0.6069 - val_accuracy: 0.8592
# Epoch 18/100
# 9/9 [==============================] - 1s 74ms/step - loss: 0.4555 - accuracy: 0.9261 - val_loss: 0.5399 - val_accuracy: 0.8732
# Epoch 19/100
# 9/9 [==============================] - 1s 78ms/step - loss: 0.4344 - accuracy: 0.9296 - val_loss: 0.5492 - val_accuracy: 0.8451
# Epoch 20/100
# 9/9 [==============================] - 1s 81ms/step - loss: 0.4178 - accuracy: 0.9296 - val_loss: 0.5899 - val_accuracy: 0.8592
# Epoch 21/100
# 9/9 [==============================] - 1s 80ms/step - loss: 0.3872 - accuracy: 0.9296 - val_loss: 0.6980 - val_accuracy: 0.8310
# Epoch 22/100
# 9/9 [==============================] - 1s 83ms/step - loss: 0.3984 - accuracy: 0.9296 - val_loss: 0.5539 - val_accuracy: 0.8592
# Epoch 23/100
# 9/9 [==============================] - 1s 78ms/step - loss: 0.4147 - accuracy: 0.9366 - val_loss: 0.5746 - val_accuracy: 0.8732
# Epoch 24/100
# 9/9 [==============================] - 1s 85ms/step - loss: 0.3877 - accuracy: 0.9296 - val_loss: 0.5632 - val_accuracy: 0.8592
# Epoch 25/100
# 9/9 [==============================] - 1s 82ms/step - loss: 0.3505 - accuracy: 0.9472 - val_loss: 0.7427 - val_accuracy: 0.8169
# Epoch 26/100
# 9/9 [==============================] - 1s 87ms/step - loss: 0.3747 - accuracy: 0.9331 - val_loss: 0.6002 - val_accuracy: 0.8451
# Epoch 27/100
# 9/9 [==============================] - 1s 84ms/step - loss: 0.3341 - accuracy: 0.9472 - val_loss: 0.5383 - val_accuracy: 0.9014
# Epoch 28/100
# 9/9 [==============================] - 1s 85ms/step - loss: 0.3364 - accuracy: 0.9331 - val_loss: 0.6055 - val_accuracy: 0.8592
# Epoch 29/100
# 9/9 [==============================] - 1s 82ms/step - loss: 0.3242 - accuracy: 0.9437 - val_loss: 0.5307 - val_accuracy: 0.8732
# Epoch 30/100
# 9/9 [==============================] - 1s 79ms/step - loss: 0.2940 - accuracy: 0.9472 - val_loss: 0.6850 - val_accuracy: 0.8169
# Epoch 31/100
# 9/9 [==============================] - 1s 75ms/step - loss: 0.3255 - accuracy: 0.9366 - val_loss: 0.7224 - val_accuracy: 0.8169
# Epoch 32/100
# 9/9 [==============================] - 1s 76ms/step - loss: 0.3222 - accuracy: 0.9472 - val_loss: 0.5970 - val_accuracy: 0.8592
# Epoch 33/100
# 9/9 [==============================] - 1s 77ms/step - loss: 0.2984 - accuracy: 0.9472 - val_loss: 0.5795 - val_accuracy: 0.8592
# Epoch 34/100
# 9/9 [==============================] - 1s 74ms/step - loss: 0.2739 - accuracy: 0.9437 - val_loss: 0.5945 - val_accuracy: 0.8451
# Epoch 35/100
# 9/9 [==============================] - 1s 81ms/step - loss: 0.2685 - accuracy: 0.9542 - val_loss: 0.6082 - val_accuracy: 0.8310
# Epoch 36/100
# 9/9 [==============================] - 1s 82ms/step - loss: 0.2796 - accuracy: 0.9507 - val_loss: 0.7189 - val_accuracy: 0.8028
# Epoch 37/100
# 9/9 [==============================] - 1s 77ms/step - loss: 0.3116 - accuracy: 0.9366 - val_loss: 0.5524 - val_accuracy: 0.8451
# Epoch 38/100
# 9/9 [==============================] - 1s 80ms/step - loss: 0.2688 - accuracy: 0.9613 - val_loss: 0.5832 - val_accuracy: 0.8592
# Epoch 39/100
# 9/9 [==============================] - 1s 80ms/step - loss: 0.2450 - accuracy: 0.9577 - val_loss: 0.6289 - val_accuracy: 0.8310
# Epoch 40/100
# 9/9 [==============================] - 1s 75ms/step - loss: 0.2332 - accuracy: 0.9648 - val_loss: 0.6326 - val_accuracy: 0.8732
# Epoch 41/100
# 9/9 [==============================] - 1s 74ms/step - loss: 0.2294 - accuracy: 0.9613 - val_loss: 0.6873 - val_accuracy: 0.8169
# Epoch 42/100
# 9/9 [==============================] - 1s 70ms/step - loss: 0.2306 - accuracy: 0.9542 - val_loss: 0.6677 - val_accuracy: 0.8169
# Epoch 43/100
# 9/9 [==============================] - 1s 71ms/step - loss: 0.2294 - accuracy: 0.9613 - val_loss: 0.5817 - val_accuracy: 0.9014
# Epoch 44/100
# 9/9 [==============================] - 1s 86ms/step - loss: 0.2208 - accuracy: 0.9648 - val_loss: 0.6952 - val_accuracy: 0.8169
# Epoch 45/100
# 9/9 [==============================] - 1s 90ms/step - loss: 0.2196 - accuracy: 0.9718 - val_loss: 0.7139 - val_accuracy: 0.8169
# Epoch 46/100
# 9/9 [==============================] - 1s 87ms/step - loss: 0.2199 - accuracy: 0.9542 - val_loss: 0.6068 - val_accuracy: 0.8592
# Epoch 47/100
# 9/9 [==============================] - 1s 87ms/step - loss: 0.2220 - accuracy: 0.9648 - val_loss: 0.6550 - val_accuracy: 0.8451
# Epoch 48/100
# 9/9 [==============================] - 1s 84ms/step - loss: 0.2133 - accuracy: 0.9648 - val_loss: 0.5757 - val_accuracy: 0.9155
# Epoch 49/100
# 9/9 [==============================] - 1s 80ms/step - loss: 0.2500 - accuracy: 0.9577 - val_loss: 0.6648 - val_accuracy: 0.8310
# Epoch 50/100
# 9/9 [==============================] - 1s 79ms/step - loss: 0.2323 - accuracy: 0.9648 - val_loss: 0.6091 - val_accuracy: 0.8873
# Epoch 51/100
# 9/9 [==============================] - 1s 78ms/step - loss: 0.2217 - accuracy: 0.9683 - val_loss: 0.5757 - val_accuracy: 0.8873
# Epoch 52/100
# 9/9 [==============================] - 1s 83ms/step - loss: 0.2202 - accuracy: 0.9613 - val_loss: 0.7528 - val_accuracy: 0.8451
# Epoch 53/100
# 9/9 [==============================] - 1s 84ms/step - loss: 0.2010 - accuracy: 0.9789 - val_loss: 0.5825 - val_accuracy: 0.9014
# Epoch 54/100
# 9/9 [==============================] - 1s 86ms/step - loss: 0.2056 - accuracy: 0.9577 - val_loss: 0.6628 - val_accuracy: 0.8310
# Epoch 55/100
# 9/9 [==============================] - 1s 90ms/step - loss: 0.1874 - accuracy: 0.9824 - val_loss: 0.6333 - val_accuracy: 0.8873
# Epoch 56/100
# 9/9 [==============================] - 1s 85ms/step - loss: 0.2012 - accuracy: 0.9789 - val_loss: 0.6625 - val_accuracy: 0.8732
# Epoch 57/100
# 9/9 [==============================] - 1s 80ms/step - loss: 0.1927 - accuracy: 0.9789 - val_loss: 0.6204 - val_accuracy: 0.8873
# Epoch 58/100
# 9/9 [==============================] - 1s 79ms/step - loss: 0.1921 - accuracy: 0.9789 - val_loss: 0.7728 - val_accuracy: 0.8451
# Epoch 59/100
# 9/9 [==============================] - 1s 77ms/step - loss: 0.1908 - accuracy: 0.9718 - val_loss: 0.7093 - val_accuracy: 0.8732
# Epoch 60/100
# 9/9 [==============================] - 1s 88ms/step - loss: 0.2005 - accuracy: 0.9718 - val_loss: 0.6781 - val_accuracy: 0.8592
# Epoch 61/100
# 9/9 [==============================] - 1s 77ms/step - loss: 0.1875 - accuracy: 0.9789 - val_loss: 0.6616 - val_accuracy: 0.8732
# Epoch 62/100
# 9/9 [==============================] - 1s 79ms/step - loss: 0.1968 - accuracy: 0.9718 - val_loss: 0.6011 - val_accuracy: 0.8873
# Epoch 63/100
# 9/9 [==============================] - 1s 141ms/step - loss: 0.1833 - accuracy: 0.9789 - val_loss: 0.7623 - val_accuracy: 0.8310
# Epoch 64/100
# 9/9 [==============================] - 3s 296ms/step - loss: 0.1930 - accuracy: 0.9683 - val_loss: 0.6598 - val_accuracy: 0.8592
# Epoch 65/100
# 9/9 [==============================] - 3s 287ms/step - loss: 0.1749 - accuracy: 0.9859 - val_loss: 0.6670 - val_accuracy: 0.8451
# Epoch 66/100
# 9/9 [==============================] - 3s 282ms/step - loss: 0.1756 - accuracy: 0.9859 - val_loss: 0.6405 - val_accuracy: 0.8732
# Epoch 67/100
# 9/9 [==============================] - 3s 285ms/step - loss: 0.1816 - accuracy: 0.9718 - val_loss: 0.6242 - val_accuracy: 0.8873
# Epoch 68/100
# 9/9 [==============================] - 3s 285ms/step - loss: 0.1737 - accuracy: 0.9894 - val_loss: 0.6234 - val_accuracy: 0.8732
# Epoch 69/100
# 9/9 [==============================] - 3s 284ms/step - loss: 0.1734 - accuracy: 0.9789 - val_loss: 0.7434 - val_accuracy: 0.8592
# Epoch 70/100
# 9/9 [==============================] - 3s 286ms/step - loss: 0.1663 - accuracy: 0.9894 - val_loss: 0.6326 - val_accuracy: 0.8732
# Epoch 71/100
# 9/9 [==============================] - 3s 281ms/step - loss: 0.1634 - accuracy: 0.9824 - val_loss: 0.6728 - val_accuracy: 0.8592
# Epoch 72/100
# 9/9 [==============================] - 3s 297ms/step - loss: 0.1582 - accuracy: 0.9859 - val_loss: 0.6583 - val_accuracy: 0.8592
# Epoch 73/100
# 9/9 [==============================] - 2s 271ms/step - loss: 0.1600 - accuracy: 0.9894 - val_loss: 0.6945 - val_accuracy: 0.8732
# Epoch 74/100
# 9/9 [==============================] - 2s 278ms/step - loss: 0.1693 - accuracy: 0.9754 - val_loss: 0.6638 - val_accuracy: 0.8732
# Epoch 75/100
# 9/9 [==============================] - 2s 266ms/step - loss: 0.1769 - accuracy: 0.9789 - val_loss: 0.5498 - val_accuracy: 0.9014
# Epoch 76/100
# 9/9 [==============================] - 2s 265ms/step - loss: 0.1902 - accuracy: 0.9718 - val_loss: 0.6397 - val_accuracy: 0.8732
# Epoch 77/100
# 9/9 [==============================] - 2s 271ms/step - loss: 0.1992 - accuracy: 0.9648 - val_loss: 0.7241 - val_accuracy: 0.8451
# Epoch 78/100
# 9/9 [==============================] - 3s 279ms/step - loss: 0.2037 - accuracy: 0.9754 - val_loss: 0.6083 - val_accuracy: 0.8873
# Epoch 79/100
# 9/9 [==============================] - 2s 272ms/step - loss: 0.1761 - accuracy: 0.9824 - val_loss: 0.8117 - val_accuracy: 0.8592
# Epoch 80/100
# 9/9 [==============================] - 2s 271ms/step - loss: 0.1677 - accuracy: 0.9894 - val_loss: 0.6485 - val_accuracy: 0.8873
# Epoch 81/100
# 9/9 [==============================] - 2s 280ms/step - loss: 0.1629 - accuracy: 0.9859 - val_loss: 0.9022 - val_accuracy: 0.8310
# Epoch 82/100
# 9/9 [==============================] - 2s 275ms/step - loss: 0.1565 - accuracy: 0.9894 - val_loss: 0.7024 - val_accuracy: 0.8592
# Epoch 83/100
# 9/9 [==============================] - 3s 282ms/step - loss: 0.1713 - accuracy: 0.9789 - val_loss: 0.6581 - val_accuracy: 0.8873
# Epoch 84/100
# 9/9 [==============================] - 3s 294ms/step - loss: 0.1698 - accuracy: 0.9789 - val_loss: 0.7889 - val_accuracy: 0.8310
# Epoch 85/100
# 9/9 [==============================] - 2s 280ms/step - loss: 0.1683 - accuracy: 0.9754 - val_loss: 0.7644 - val_accuracy: 0.8592
# Epoch 86/100
# 9/9 [==============================] - 3s 284ms/step - loss: 0.1711 - accuracy: 0.9754 - val_loss: 0.6070 - val_accuracy: 0.8873
# Epoch 87/100
# 9/9 [==============================] - 2s 278ms/step - loss: 0.1485 - accuracy: 0.9930 - val_loss: 0.8509 - val_accuracy: 0.8592
# Epoch 88/100
# 9/9 [==============================] - 3s 283ms/step - loss: 0.1606 - accuracy: 0.9718 - val_loss: 0.6723 - val_accuracy: 0.8592
# Epoch 89/100
# 9/9 [==============================] - 2s 278ms/step - loss: 0.1547 - accuracy: 0.9894 - val_loss: 0.6960 - val_accuracy: 0.8732
# Epoch 90/100
# 9/9 [==============================] - 2s 281ms/step - loss: 0.1610 - accuracy: 0.9824 - val_loss: 0.7150 - val_accuracy: 0.8732
# Epoch 91/100
# 9/9 [==============================] - 3s 282ms/step - loss: 0.1615 - accuracy: 0.9859 - val_loss: 0.6351 - val_accuracy: 0.8732
# Epoch 92/100
# 9/9 [==============================] - 2s 274ms/step - loss: 0.1462 - accuracy: 0.9859 - val_loss: 0.7042 - val_accuracy: 0.8451
# Epoch 93/100
# 9/9 [==============================] - 3s 287ms/step - loss: 0.1606 - accuracy: 0.9859 - val_loss: 0.6155 - val_accuracy: 0.8732
# Epoch 94/100
# 9/9 [==============================] - 3s 287ms/step - loss: 0.1476 - accuracy: 0.9894 - val_loss: 0.8349 - val_accuracy: 0.8310
# Epoch 95/100
# 9/9 [==============================] - 2s 276ms/step - loss: 0.1478 - accuracy: 0.9789 - val_loss: 0.7318 - val_accuracy: 0.8592
# Epoch 96/100
# 9/9 [==============================] - 3s 304ms/step - loss: 0.1431 - accuracy: 0.9930 - val_loss: 0.6238 - val_accuracy: 0.8873
# Epoch 97/100
# 9/9 [==============================] - 3s 283ms/step - loss: 0.1472 - accuracy: 0.9824 - val_loss: 0.6166 - val_accuracy: 0.8873
# Epoch 98/100
# 9/9 [==============================] - 2s 272ms/step - loss: 0.1412 - accuracy: 0.9894 - val_loss: 0.6889 - val_accuracy: 0.8732
# Epoch 99/100
# 9/9 [==============================] - 2s 269ms/step - loss: 0.1388 - accuracy: 0.9894 - val_loss: 0.7055 - val_accuracy: 0.8732
# Epoch 100/100
# 9/9 [==============================] - 2s 271ms/step - loss: 0.1375 - accuracy: 0.9930 - val_loss: 0.6424 - val_accuracy: 0.8873
# <AxesSubplot:>

# %% [markdown]
# ## Saving a TensorFlow Lite Model

# %% [markdown]
# Choose an appropriate output file name for your `.tflite` file.  It may help to use version numbers, and keep track of versions

# %%
output_filename = './mini_proj_model_v01_02.tflite'

# %% [markdown]
# Convert your model (in the variable `model`) and save the `.tflite` file

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

converter.target_spec.supported_types = [tf.float16]
tflite_fp16_model = converter.convert()

# This will save your model with the a file name tflite_model_fp16_file.tflite. You can uplaod this model file
# in your JetRacer a

with open(output_filename, 'wb') as f:
    f.write(tflite_fp16_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\joskn\AppData\Local\Temp\tmpjua1dhp3\assets
# INFO:tensorflow:Assets written to: C:\Users\joskn\AppData\Local\Temp\tmpjua1dhp3\assets
